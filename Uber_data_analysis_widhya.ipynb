# %% [markdown]
# # Uber Data Analysis

# %% [markdown]
# Ishika Tailor

# %% [markdown]
# # Microtask: 1

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("Desktop/Uber-dataset/uber-raw-data-apr14.csv")
df1.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
df2=pd.read_csv("Desktop/Uber-dataset/uber-raw-data-jun14.csv")
df2.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  6/1/2014 0:00:00  40.7293 -73.9920  B02512
# 1  6/1/2014 0:01:00  40.7131 -74.0097  B02512
# 2  6/1/2014 0:04:00  40.3461 -74.6610  B02512
# 3  6/1/2014 0:04:00  40.7555 -73.9833  B02512
# 4  6/1/2014 0:07:00  40.6880 -74.1831  B02512

# %%
df3=pd.read_csv("Desktop/Uber-dataset/uber-raw-data-jul14.csv")

# %%
df4=pd.read_csv("Desktop/Uber-dataset/uber-raw-data-aug14.csv")

# %%
df5=pd.read_csv("Desktop/Uber-dataset/uber-raw-data-sep14.csv")

# %%
df6=pd.read_csv("Desktop/Uber-dataset/uber-raw-data-may14.csv")

# %%
df= pd.concat([df1,df2,df3,df4,df5,df6])
df
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1         4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2         4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3         4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4         4/1/2014 0:33:00  40.7594 -73.9722  B02512
# ...                    ...      ...      ...     ...
# 652430  5/31/2014 23:45:00  40.7309 -74.0014  B02764
# 652431  5/31/2014 23:52:00  40.7528 -73.9798  B02764
# 652432  5/31/2014 23:55:00  40.7158 -73.9519  B02764
# 652433  5/31/2014 23:56:00  40.6961 -73.8997  B02764
# 652434  5/31/2014 23:59:00  40.7393 -73.9919  B02764
#
# [4534327 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4534327 entries, 0 to 652434
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date/Time  object
#  1   Lat        float64
#  2   Lon        float64
#  3   Base       object
# dtypes: float64(2), object(2)
# memory usage: 173.0+ MB

# %%
df.isnull().sum()
# Out:
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %%
df['Date/Time']=pd.to_datetime(df['Date/Time'])

# %%
df.dtypes
# Out:
# Date/Time    datetime64[ns]
# Lat                 float64
# Lon                 float64
# Base                 object
# dtype: object

# %%
df['month']=df['Date/Time'].dt.month

# %%
df['date']=df['Date/Time'].dt.date

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['hour']=df['Date/Time'].dt.hour

# %%
df['DayOfWeek']=df['Date/Time'].dt.dayofweek

# %%
df['OnlyDate']=df['Date/Time'].dt.strftime("%d")

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  month        date  hour  \
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512      4  2014-04-01     0
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512      4  2014-04-01     0
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512      4  2014-04-01     0
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512      4  2014-04-01     0
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512      4  2014-04-01     0
#
#    DayOfWeek OnlyDate
# 0          1       01
# 1          1       01
# 2          1       01
# 3          1       01
# 4          1       01

# %%
sns.catplot(x="hour",y="Base",kind='bar',data=df)

# %% [markdown]
# # Microtask: 2

# %%
del df["Lat"]

# %%
del df["Lon"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4534327 entries, 0 to 652434
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date/Time  datetime64[ns]
#  1   Base       object
#  2   month      int64
#  3   date       object
#  4   hour       int64
#  5   DayOfWeek  int64
#  6   OnlyDate   object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 276.8+ MB

# %%
dff=df

# %%
df_date= dff['date'].value_counts().to_frame()

df_date.rename(columns={'date':'value'},inplace=True)

df_date = df_date.reset_index()

df_date.rename(columns={'index':'date'},inplace=True)

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    183 non-null    datetime64[ns]
#  1   value   183 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.0 KB

# %%
df_final=df_date

# %%
df_date=df_date.sort_values(by='date',ascending=True)

# %%
df_date=df_date.set_index('date')

# %%
df_date.index.freq="D"

# %%
#fit1 = ExponentialSmoothing(df_date, seasonal_periods=4, trend='add', seasonal='add').fit()

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 183 entries, 2014-04-01 to 2014-09-30
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   183 non-null    int64
# dtypes: int64(1)
# memory usage: 2.9 KB

# %%
df_date.plot(figsize=(12,8))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test = train_test_split(df_date,random_state=0,test_size=0.1)

# %%
X_train
# Out:
#             value
# date
# 2014-09-03  32631
# 2014-06-11  25716
# 2014-05-26  10202
# 2014-05-08  27513
# 2014-08-24  22036
# ...           ...
# 2014-07-13  21082
# 2014-06-07  20889
# 2014-07-27  22590
# 2014-05-18  16508
# 2014-09-20  38864
#
# [164 rows x 1 columns]

# %%
X_train.plot()

# %%
X_train.asfreq('M').index
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 164 entries, 2014-09-03 to 2014-09-20
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   164 non-null    int64
# dtypes: int64(1)
# memory usage: 7.6 KB

# %%
x_test.plot()

# %% [markdown]
# # Microtask: 3

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
model = ExponentialSmoothing(X_train['value'],trend='add',seasonal='mul',seasonal_periods=12).fit()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
model.forecast(36).plot()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
df_hour= dff['hour'].value_counts()

# %%
df_hour.to_frame()
# Out:
#       hour
# 17  336190
# 18  324679
# 16  313400
# 19  294513
# 20  284604
# 21  281460
# 15  275466
# 22  241858
# 14  230625
# 13  195877
# 7   193094
# 8   190504
# 12  170452
# 23  169190
# 11  165703
# 9   159967
# 10  159148
# 6   143213
# 0   103836
# 5    83939
# 1    67227
# 4    55230
# 3    48287
# 2    45865

# %%
#df_hour.rename(columns={'hour':'value'},inplace=True)

df_hour = df_hour.reset_index()

df_hour.rename(columns={'index':'index'},inplace=True)

# %%
df_hour.head()
# Out:
#    index    hour
# 0     17  336190
# 1     18  324679
# 2     16  313400
# 3     19  294513
# 4     20  284604

# %%
Y_train, y_test = train_test_split(df_hour,random_state=0,test_size=0.1)

# %%
df_hour.plot()

# %% [markdown]
# # **Microtask: 4**

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(df_date['value'],order=(1,1,0))
model_fit=model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.value   No. Observations:                  182
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -1793.699
# Method:                       css-mle   S.D. of innovations           4612.381
# Date:                Thu, 04 Feb 2021   AIC                           3593.397
# Time:                        14:02:59   BIC                           3603.009
# Sample:                    04-02-2014   HQIC                          3597.294
#                          - 09-30-2014
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           103.7637    394.167      0.263      0.792    -668.790     876.318
# ar.L1.D.value     0.1333      0.073      1.814      0.070      -0.011       0.277
# ...

# %%
df_date['forecast']=model_fit.predict(start=10,end=130,dynamic=True)
df_date[['value','forecast']].plot(figsize=(12,8))

# %% [markdown]
# **Data is seasonal , so above model is not working well.**

# %%
import statsmodels.api as sm

# %%
#q=0

model=sm.tsa.statespace.SARIMAX(df_date['value'],order=(1,1,0),seasonal_order=(1,1,0,12))
result=model.fit()

# %%
df_date['forecast']=result.predict(start=90,end=103,dynamic=True)
df_date[['value','forecast']].plot(figsize=(12,8))

# %%
#p=0

model=sm.tsa.statespace.SARIMAX(df_date['value'],order=(0,1,1),seasonal_order=(0,1,1,12))
result1=model.fit()

# %%
df_date['forecast']=result1.predict(start=90,end=130,dynamic=True)
df_date[['value','forecast']].plot(figsize=(12,8))

# %% [markdown]
# # Microtask: 5

# %%
#Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# Neural network
model = Sequential()
model.add(Dense(16, input_dim=1, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='softmax'))

# %%
X = df_hour.index.values
y = df_hour.hour.values

# %%
X;

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=64)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 10/10
# ...

# %%
y_pred = model.predict(X_test)
#Converting predictions to label
pred = list()
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))
#Converting one hot encoded test label to label
test = list()
for i in range(len(y_test)):
    test.append(np.argmax(y_test[i]))

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(pred,test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 100.0
